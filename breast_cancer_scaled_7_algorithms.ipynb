# %%
from sklearn.datasets import load_breast_cancer
dataset = load_breast_cancer()
import pandas as pd
import numpy as np
cancer_df = pd.DataFrame(np.c_[dataset['data'],dataset['target']], 
                         columns = np.append(dataset['feature_names'],['target_names']))

# %%
cancer_df2 = cancer_df.drop(['target_names'], axis=1)

# %% [markdown]
# # plot correlation of target with all other features

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(16,5))
fig = sns.barplot(cancer_df2.corrwith(cancer_df.target_names).index, cancer_df2.corrwith(cancer_df.target_names))
fig.tick_params(labelrotation = 90)

# %%
X = cancer_df.drop(['target_names'],axis=1)
y = cancer_df['target_names']

# %%
X_train,X_test,y_train,y_test=model_selection.train_test_split(X,y,test_size=0.20,random_state=5)

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train_transformed = sc.fit_transform(X_train)

# %%
X_train_transformed_df = pd.DataFrame(X_train_transformed)

# %%
X_train_transformed_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.250147 -0.767966 -0.311695 -0.324081 -0.799677 -0.978364 -1.093146
# 1 -0.783184 -0.355792 -0.799459 -0.728135 -0.552631 -0.966145 -0.749131
# 2  1.163560  0.649912  1.092208  1.106126 -1.611296 -0.310039  0.326786
# 3 -1.012043  0.268357 -0.898023 -0.908858 -0.399563  1.258386  1.862319
# 4  1.545956  1.040888  1.585027  1.491080  0.452637  1.057356  1.560953
#
#          7         8         9   ...        20        21        22        23  \
# 0 -1.181031 -0.639199 -0.532184  ... -0.371365 -0.807810 -0.443416 -0.423707
# 1 -0.708844 -0.753267 -0.504517  ... -0.663424  1.804030 -0.658985 -0.640708
# 2  0.270188 -0.131414 -1.338913  ...  0.777546 -0.108357  0.710641  0.685887
# 3  0.313576  1.406659  3.189834  ... -1.135873 -0.417762 -0.925259 -0.958700
# 4  1.097494  0.633943 -0.377828  ...  1.183422  0.851128  1.202126  1.040671
#
#          24        25        26        27        28        29
# ...

# %%
X_train.head(5)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 306        13.20         15.82           84.07      537.3          0.08511
# 410        11.36         17.57           72.49      399.8          0.08858
# 197        18.08         21.84          117.40     1024.0          0.07371
# 376        10.57         20.22           70.15      338.3          0.09073
# 244        19.40         23.50          129.10     1155.0          0.10270
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 306           0.05251        0.001461             0.003261         0.1632
# 410           0.05313        0.027830             0.021000         0.1601
# 197           0.08642        0.110300             0.057780         0.1770
# 376           0.16600        0.228000             0.059410         0.2188
# 244           0.15580        0.204900             0.088860         0.1978
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %%
cancer_df_transformed = sc.fit_transform(cancer_df)
cancer_df_transformed = pd.DataFrame(cancer_df_transformed)

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
cancer_df_transformed.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874
# 1  1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
# 2  1.579888  0.456187  1.566503  1.558884  0.942210  1.052926  1.363478
# 3 -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909  1.915897
# 4  1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340  1.371011
#
#          7         8         9   ...        21        22        23        24  \
# 0  2.532475  2.217515  2.255747  ... -1.359293  2.303601  2.001237  1.307686
# 1  0.548144  0.001392 -0.868652  ... -0.369203  1.535126  1.890489 -0.375612
# 2  2.037231  0.939685 -0.398008  ... -0.023974  1.347475  1.456285  0.527407
# 3  1.451707  2.867383  4.910919  ...  0.133984 -0.249939 -0.550021  3.394275
# 4  1.428493 -0.009560 -0.562450  ... -1.466770  1.338539  1.220724  0.220556
#
#          25        26        27        28        29        30
# ...

# %%
cancer_df.std()
# Out:
# mean radius                  3.524049
# mean texture                 4.301036
# mean perimeter              24.298981
# mean area                  351.914129
# mean smoothness              0.014064
# mean compactness             0.052813
# mean concavity               0.079720
# mean concave points          0.038803
# mean symmetry                0.027414
# mean fractal dimension       0.007060
# radius error                 0.277313
# texture error                0.551648
# perimeter error              2.021855
# area error                  45.491006
# smoothness error             0.003003
# compactness error            0.017908
# concavity error              0.030186
# concave points error         0.006170
# symmetry error               0.008266
# fractal dimension error      0.002646
# worst radius                 4.833242
# worst texture                6.146258
# worst perimeter             33.602542
# worst area                 569.356993
# worst smoothness             0.022832
# ...

# %%
cancer_df_transformed.std()
# Out:
# 0     1.00088
# 1     1.00088
# 2     1.00088
# 3     1.00088
# 4     1.00088
# 5     1.00088
# 6     1.00088
# 7     1.00088
# 8     1.00088
# 9     1.00088
# 10    1.00088
# 11    1.00088
# 12    1.00088
# 13    1.00088
# 14    1.00088
# 15    1.00088
# 16    1.00088
# 17    1.00088
# 18    1.00088
# 19    1.00088
# 20    1.00088
# 21    1.00088
# 22    1.00088
# 23    1.00088
# 24    1.00088
# 25    1.00088
# 26    1.00088
# 27    1.00088
# 28    1.00088
# 29    1.00088
# 30    1.00088
# dtype: float64

# %%
cancer_df.mean()
# Out:
# mean radius                 14.127292
# mean texture                19.289649
# mean perimeter              91.969033
# mean area                  654.889104
# mean smoothness              0.096360
# mean compactness             0.104341
# mean concavity               0.088799
# mean concave points          0.048919
# mean symmetry                0.181162
# mean fractal dimension       0.062798
# radius error                 0.405172
# texture error                1.216853
# perimeter error              2.866059
# area error                  40.337079
# smoothness error             0.007041
# compactness error            0.025478
# concavity error              0.031894
# concave points error         0.011796
# symmetry error               0.020542
# fractal dimension error      0.003795
# worst radius                16.269190
# worst texture               25.677223
# worst perimeter            107.261213
# worst area                 880.583128
# worst smoothness             0.132369
# ...

# %% [markdown]
# # support vector machine classifier

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)
y_pred_svm = svm_classifier.predict(X_test)
accuracy_score(y_test, y_pred_svm)
# Out:
# 0.9385964912280702

# %%
X_test_transformed = sc.fit_transform(X_test)

# %%
svm_classifier = SVC()
svm_classifier.fit(X_train_transformed, y_train)
y_pred_svm = svm_classifier.predict(X_test_transformed)
accuracy_score(y_test, y_pred_svm)
# Out:
# 0.9473684210526315

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=30000)
logreg.fit(X_train, y_train)
y_pred_logreg = logreg.predict(X_test)
accuracy_score(y_test, y_pred_logreg)
# Out:
# 0.9649122807017544

# %%
logreg.fit(X_train_transformed, y_train)
y_pred_logreg = logreg.predict(X_test_transformed)
accuracy_score(y_test, y_pred_logreg)
# Out:
# 0.9736842105263158

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
accuracy_score(y_test, y_pred_knn)
# Out:
# 0.9385964912280702

# %%
knn.fit(X_train_transformed, y_train)
y_pred_knn = knn.predict(X_test_transformed)
accuracy_score(y_test, y_pred_knn)
# Out:
# 0.956140350877193

# %% [markdown]
# # naive bayes

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
y_pred_nb = nb.predict(X_test)
accuracy_score(y_test, y_pred_nb)
# Out:
# 0.9473684210526315

# %%
nb.fit(X_train_transformed, y_train)
y_pred_nb = nb.predict(X_test_transformed)
accuracy_score(y_test, y_pred_nb)
# Out:
# 0.9473684210526315

# %% [markdown]
# # decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
accuracy_score(y_test, y_pred_dt)
# Out:
# 0.9385964912280702

# %%
dt.fit(X_train_transformed, y_train)
y_pred_dt = dt.predict(X_test_transformed)
accuracy_score(y_test, y_pred_dt)
# Out:
# 0.9649122807017544

# %% [markdown]
# # random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.9736842105263158

# %%
rf.fit(X_train_transformed, y_train)
y_pred_rf = rf.predict(X_test_transformed)
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.9473684210526315

# %% [markdown]
# # ada boost classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ab = AdaBoostClassifier()
ab.fit(X_train, y_train)
y_pred_ab = ab.predict(X_test)
accuracy_score(y_test, y_pred_ab)
# Out:
# 0.9736842105263158

# %%
ab.fit(X_train_transformed, y_train)
y_pred_ab = ab.predict(X_test_transformed)
accuracy_score(y_test, y_pred_ab)
# Out:
# 0.9649122807017544
